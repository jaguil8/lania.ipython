# %% [markdown]
# # Dia 2 Libreta 6
# En esta libreta usaremos un clasificador para detectar rostros en imagenes; despues realizaran el ejercicio de tomar una foto de su rostro con el dispositivo, extraerlo del mismo a la mnaquina y aplciar el detector.
#
# Finalmente, trataremos de implementarlo en el dispositivo...
#
# Algo de informacion [tomada de este sitio](https://realpython.com/blog/python/face-recognition-with-python/)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys, os, re, time
import numpy as np
import cv2

# %%
pic = os.path.join('.','ZuzanaB.jpg')

img=cv2.imread(pic)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
caras_cascada=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

caras = caras_cascada.detectMultiScale(gray, 1.3, 4)

print "Encontramos {0} faces!".format(len(caras))

# %%
i=img.copy()
for (x,y,w,h) in caras:
    cv2.rectangle(i, (x,y), (x+w,y+h), (0,255,0), 2)
plt.imshow(i)

# %%
import android
droide=android.Android()

# %%
droide.ttsSpeak("Hola listo para el registro")
# Out:
# Result(id=0, result=None, error=None)

# %%
droide.cameraCapturePicture('/sdcard/DCIM/CAMERA/carota.jpg')
# Out:
# Result(id=0, result={u'takePicture': True, u'autoFocus': True, u'cameraId': 0}, error=None)

# %%
# !adb pull /sdcard/DCIM/CAMERA/carota.jpg
# Out:
# 5287 KB/s (4934957 bytes in 0.911s)

# %%
droide.getLaunchableApplications().result
# Out:
# {u'API Veracruz': u'com.apiver.activity.Inicio',
#  u'Administrador inteligente': u'com.samsung.android.sm.app.dashboard.SmartManagerDashBoardActivity',
#  u'Adobe AIR': u'com.adobe.air.AdobeAIRMainActivity',
#  u'Adobe Acrobat': u'com.adobe.reader.AdobeReader',
#  u'AirDroid': u'com.sand.airdroid.ui.splash.SplashActivity_',
#  u'Ajustes': u'com.android.settings.Settings',
#  u'All-in-One Remote': u'com.hp.printercontrol.base.UiDrawerBaseAct',
#  u'Amex to Go': u'com.americanexpress.android.intl.app.view.activity.SplashActivity',
#  u'Android Sensing Playground': u'root.gast.playground.GastAppActivity',
#  u'Asphalt 8': u'com.gameloft.android.ANMP.GloftA8HM.MainActivity',
#  u'Asphalt Nitro': u'com.gameloft.android.GloftANIM.Start',
#  u'AudioRecord': u'mx.lania.audiorecord.MainActivity',
#  u'Authenticator': u'com.google.android.apps.authenticator.AuthenticatorActivity',
#  u'Banamex': u'com.citibanamex.banamexmobile.CitiBanamex',
#  u'Barcode Scanner': u'com.google.zxing.client.android.CaptureActivity',
#  u"Beep'nGo": u'com.mobeam.beepngo.main.MainActivity',
#  u'B\xfasqueda por voz': u'com.google.android.googlequicksearchbox.VoiceSearchActivity',
#  u'Calculadora': u'com.sec.android.app.popupcalculator.Calculator',
#  u'Cerberus': u'com.lsdroid.cerberus.StartActivity',
#  u'Chrome': u'com.google.android.apps.chrome.Main',
#  u'Cin\xe9polis': u'com.ia.cinepolis.android.smartphone.SplashScreen',
#  u'Cisco Technical Support': u'com.cisco.swtg.cts.activities.CTSLauncher',
#  u'Config. de Google': u'com.google.android.gms.app.settings.GoogleSettingsActivity',
#  u'Contactos': u'com.android.contacts.activities.PeopleActivity',
#  u'Correo': u'com.samsung.android.email.ui.activity.MessageListXL',
#  u'Cuenta Microsoft': u'com.microsoft.onlineid.authenticator.LauncherActivity',
#  u'CurrentLocationActivity': u'mx.lania.currentlocationactivity.MyActivity',
#  u'C\xe1mara': u'com.sec.android.app.camera.Camera',
#  u'Dropbox': u'com.dropbox.android.activity.DropboxBrowser',
#  u'Duolingo': u'com.duolingo.app.LoginActivity',
#  u'Earth': u'com.google.earth.EarthActivity',
#  u'Escritorio remoto': u'org.chromium.chromoting.Chromoting',
#  u'Evernote': u'com.evernote.ui.HomeActivity',
#  u'Excel': u'com.microsoft.office.apphost.LaunchActivity',
#  u'Facebook': u'com.facebook.katana.LoginActivity',
#  u'File Manager': u'org.openintents.filemanager.FileManagerActivity',
#  u'Fing': u'com.overlook.android.fing.FingActivity',
#  u'Flipboard': u'flipboard.activities.LaunchActivityAlias',
#  u'Fotos': u'com.google.android.apps.plus.phone.ConversationListActivity',
#  u'Galaxy Apps': u'com.sec.android.app.samsungapps.SamsungAppsMainActivity',
#  u'Galer\xeda': u'com.sec.android.gallery3d.app.GalleryOpaqueActivity',
#  u'Geo News': u'com.sec.android.GeoLookout.activity.DisasterDashboardActivity',
#  u'Gmail': u'com.google.android.gm.ConversationListActivityGmail',
#  u'Goodreads': u'com.goodreads.android.activity.MainActivity',
#  u'Google': u'com.google.android.googlequicksearchbox.SearchActivity',
#  u'Google Drive': u'com.google.android.apps.docs.app.NewMainProxyActivity',
#  u'Google+': u'com.google.android.apps.plus.phone.HomeActivity',
#  u'Grabadora de Voz': u'com.sec.android.app.voicenote.main.VNMainActivity',
#  u'HP ePrint': u'com.hp.android.print.welcome.WelcomeActivity',
#  u'Hangouts': u'com.google.android.talk.SigningInActivity',
#  u'Hobbit: RTM': u'com.kabam.fortress.KOMActivity',
#  u'Inbox': u'com.google.android.apps.bigtop.activities.InitActivity',
#  u'Instagram': u'com.instagram.android.activity.MainTabActivity',
#  u'Internet': u'com.sec.android.app.sbrowser.SBrowserMainActivity',
#  u'Jabber Voice': u'com.cisco.soundwave.ui.JabberLauncherActivity',
#  u'Jawbone Companion': u'com.jawbone.companion.EULAActivity',
#  u'Jetpack Joyride': u'com.halfbrick.mortar.MortarGameActivity',
#  u'La Gaceta FCE': u'com.fondodeculturaeconomica.gaceta.LibraryActivity',
#  u'Layout': u'com.instagram.layout.LayoutActivity',
#  u'Lector \xd3ptico': u'com.sec.android.app.ocr3.OCR',
#  u'LinkedIn': u'com.linkedin.android.authenticator.LaunchActivity',
#  u'Map': u'mx.lania.mapsactivity.MapsActivity',
#  u'Mapa Estelar': u'com.escapistgames.starchartgoogleplay.StarChart',
#  u'Maps': u'com.google.android.maps.MapsActivity',
#  u'Mensajes': u'com.android.mms.ui.ConversationComposer',
#  u'Messenger': u'com.facebook.orca.auth.StartScreenActivity',
#  u'Mi Telcel': u'com.speedymovil.wire.Login',
#  u'Mis Archivos': u'com.sec.android.app.myfiles.common.MainActivity',
#  u'MusicPlayer2': u'mx.lania.musicplayer2.MainActivity',
#  u'M\xfasica': u'com.sec.android.app.music.common.activity.MusicMainActivity',
#  u'Netflix': u'com.netflix.mediaclient.ui.launch.UIWebViewActivity',
#  u'Notas': u'com.samsung.android.app.memo.Main',
#  u'Office Mobile': u'com.microsoft.office.officehub.OHubAppLaunchActivity',
#  u'OneDrive': u'com.microsoft.skydrive.MainActivity',
#  u'OneNote': u'com.microsoft.office.onenote.ui.ONMSplashActivity',
#  u'PAYBACK m\xf3vil': u'core.payback.client.android.controller.activity.SplashActivity',
#  u'PayPal': u'com.paypal.android.p2pmobile.activity.IntroActivity',
#  u'Peel Smart Remote': u'com.peel.main.Main',
#  u'Periscope': u'tv.periscope.android.LaunchActivity',
#  u'Photo Grid': u'com.roidapp.photogrid.MainPage',
#  u'PitchLab Lite': u'com.symbolic.pitchlab.ActivityCrashlogs',
#  u'Play Juegos': u'com.google.android.gms.games.ui.destination.main.MainActivity',
#  u'Play Kiosco': u'com.google.apps.dots.android.app.activity.CurrentsStartActivity',
#  u'Play Libros': u'com.google.android.apps.books.app.BooksActivity',
#  u'Play M\xfasica': u'com.android.music.activitymanagement.TopLevelActivity',
#  u'Play Pel\xedculas': u'com.google.android.youtube.videos.EntryPoint',
#  u'Play Store': u'com.android.vending.AssetBrowserActivity',
#  u'PowerPoint': u'com.microsoft.office.apphost.LaunchActivity',
#  u'Python for Android': u'com.googlecode.pythonforandroid.PythonMain',
#  u'P\xe1ginas': u'com.facebook.pages.app.activity.PagesManagerLoginActivity',
#  u'RegistroGastos': u'mx.lania.registrogastos.MainActivity',
#  u'Reloj': u'com.sec.android.app.clockpackage.ClockPackage',
#  u'Running': u'com.nike.plusgps.SplashActivity',
#  u'S Health': u'com.samsung.android.app.shealth.home.HomeMainActivity',
#  u'S Note': u'com.samsung.android.snote.control.ui.filemanager.MainHomeActivity',
#  u'S Planner': u'com.android.calendar.AllInOneActivity',
#  u'S Traductor': u'com.sec.android.app.translator.MainActivity',
#  u'S Voice': u'com.vlingo.midas.gui.ConversationActivity',
#  u'SL4A': u'com.googlecode.android_scripting.activity.ScriptManager',
#  u'Samsung Link': u'com.mfluent.asp.ui.MobileChargesNotificationActivity',
#  u'SensorList': u'mx.lania.sensorlist.MainActivity',
#  u'SideSync': u'com.sec.android.sidesync30.ui.SideSyncActivity',
#  u'Skype': u'com.skype.raider.Main',
#  u'Smart Switch': u'com.sec.android.easyMover.DistributionActivity',
#  u'SnapBizCard': u'com.sec.android.app.bcocr.SNameCardMainActivity',
#  u'Spark': u'com.cisco.wx2.android.ui.SplashActivity',
#  u'Spider-Man': u'com.gameloft.android.LATAM.GloftSIHP.GameActivity',
#  u'Spotify': u'com.spotify.music.MainActivity',
#  u'Springfield': u'com.ea.simpsons.SimpsonsSplashScreen',
#  u'Spy Camera HD': u'com.sam.spycamera.MenuActivity',
#  u'Street View': u'com.google.android.apps.dragonfly.activities.main.MainActivity',
#  u'Superm\xf3vil': u'mx.bancosantander.supermovil.activity.home.HomeActivity',
#  u'TELCEL': u'com.android.stk.StkLauncherActivity',
#  u'TV QuickSupport': u'com.teamviewer.incomingremotecontrollib.activity.MainActivity',
#  u'TeamViewer': u'com.teamviewer.remotecontrollib.activity.MainActivity',
#  u'Telcel': u'com.telcel.contenedor.gui.activities.AppsContainerActivity',
#  u'Telcel Recarga': u'com.vesta.mobileplatform.VestaMobilePlatformActivity',
#  u'Tel\xe9fono': u'com.android.dialer.DialtactsActivity',
#  u'Traductor': u'com.google.android.apps.translate.TranslateActivity',
#  u'Transfer': u'com.citi.transfer.activities.SplashActivity',
#  u'Twitter': u'com.twitter.android.StartActivity',
#  u'Video': u'com.samsung.android.video.list.activity.VideoList',
#  u'VideoPlayer': u'mx.lania.videoplayer.MainActivity',
#  u'WhatsApp': u'com.whatsapp.Main',
#  u'Wifi Analyzer': u'com.farproc.wifi.analyzer.MainScreen',
#  u'Word': u'com.microsoft.office.apphost.LaunchActivity',
#  u'YouTube': u'com.google.android.youtube.app.honeycomb.Shell$HomeActivity',
#  u'\xc1lbum': u'com.samsung.android.app.pinboard.ui.PinboardActivity'}

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys, os, re, time
import numpy as np
import cv2
import android
droide=android.Android()
droide.cameraCapturePicture('/sdcard/DCIM/CAMERA/carota.jpg')
# !adb pull /sdcard/DCIM/CAMERA/carota.jpg
pic = os.path.join('.','carota.jpg')

img=cv2.imread(pic)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
caras_cascada=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
caras = caras_cascada.detectMultiScale(gray, 1.1, 2)
print "Encontramos {0} faces!".format(len(caras))
i=img.copy()
for (x,y,w,h) in caras:
    cv2.rectangle(i, (x,y), (x+w,y+h), (0,255,0), 2)
plt.imshow(i)
# Out:
# Encontramos 17 faces!
# 7153 KB/s (4757368 bytes in 0.649s)

# %%
droide.Camera()
# Out:
# com.googlecode.android_scripting.rpc.RpcError: Unknown RPC.
# Result(id=3, result=None, error=u'com.googlecode.android_scripting.rpc.RpcError: Unknown RPC.')
